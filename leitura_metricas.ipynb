# %% [markdown]
# # Importando as Bibliotecas

# %%
import pandas as pd
import numpy as np
import string

from scipy import spatial

from sklearn.feature_extraction.text import CountVectorizer

# %%
CELULAR = 0
FOGAO = 1
GELADEIRA = 2
NOTEBOOK = 3
TV = 4

# %% [markdown]
# # Lendo os Datasets

# %%
arquivos = ['celulares', 'fogoes', 'geladeiras', 'notebooks', 'tvs']

lista_df_pp = []
for arquivo in arquivos:

    df_pp = pd.read_csv(f"Dados/Produtos Processados Pares/metricas/{arquivo}.csv", dtype = {'ean': str})
    lista_df_pp.append(df_pp)

# %%
df_pp = lista_df_pp[CELULAR]
df_pp[["titulo_pp", "k-1", "k-1-qtd", "k-1-qtd/1", "k-10", "k-10-qtd", "k-10-qtd/10", "k-50", "k-50-qtd", "k-50-qtd/50", 'match_rank', 'match_rank/total', '1/match_rank']].describe()
# Out:
#               k-1     k-1-qtd   k-1-qtd/1        k-10    k-10-qtd  \
# count  407.000000  407.000000  407.000000  407.000000  407.000000
# mean     0.334152    0.334152    0.334152    0.751843    0.990172
# std      0.472274    0.472274    0.472274    0.432475    0.794006
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    1.000000    1.000000
# 50%      0.000000    0.000000    0.000000    1.000000    1.000000
# 75%      1.000000    1.000000    1.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    4.000000
#
#        k-10-qtd/10        k-50    k-50-qtd  k-50-qtd/50  match_rank  \
# count   407.000000  407.000000  407.000000   407.000000  407.000000
# mean      0.099017    0.906634    1.287469     0.025749   15.265356
# std       0.079401    0.291303    0.838375     0.016767   34.911194
# min       0.000000    0.000000    0.000000     0.000000    1.000000
# ...

# %%
df_pp = lista_df_pp[FOGAO]
df_pp[["titulo_pp", "k-1", "k-1-qtd", "k-1-qtd/1", "k-10", "k-10-qtd", "k-10-qtd/10", "k-50", "k-50-qtd", "k-50-qtd/50", 'match_rank', 'match_rank/total', '1/match_rank']].describe()
# Out:
#               k-1     k-1-qtd   k-1-qtd/1        k-10    k-10-qtd  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.247945    0.247945    0.247945    0.735616    1.179452
# std      0.432116    0.432116    0.432116    0.441307    1.049849
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    1.000000    1.000000
# 75%      0.000000    0.000000    0.000000    1.000000    2.000000
# max      1.000000    1.000000    1.000000    1.000000    6.000000
#
#        k-10-qtd/10        k-50    k-50-qtd  k-50-qtd/50  match_rank  \
# count   730.000000  730.000000  730.000000   730.000000   730.00000
# mean      0.117945    0.912329    1.969863     0.039397    18.69863
# std       0.104985    0.283010    1.442704     0.028854    48.50825
# min       0.000000    0.000000    0.000000     0.000000     1.00000
# ...

# %%
df_pp = lista_df_pp[GELADEIRA]
df_pp[["titulo_pp", "k-1", "k-1-qtd", "k-1-qtd/1", "k-10", "k-10-qtd", "k-10-qtd/10", "k-50", "k-50-qtd", "k-50-qtd/50", 'match_rank', 'match_rank/total', '1/match_rank']].describe()
# Out:
#               k-1     k-1-qtd   k-1-qtd/1        k-10    k-10-qtd  \
# count  318.000000  318.000000  318.000000  318.000000  318.000000
# mean     0.320755    0.320755    0.320755    0.764151    1.157233
# std      0.467502    0.467502    0.467502    0.425197    0.969794
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    1.000000    1.000000
# 50%      0.000000    0.000000    0.000000    1.000000    1.000000
# 75%      1.000000    1.000000    1.000000    1.000000    2.000000
# max      1.000000    1.000000    1.000000    1.000000    4.000000
#
#        k-10-qtd/10        k-50    k-50-qtd  k-50-qtd/50  match_rank  \
# count   318.000000  318.000000  318.000000   318.000000  318.000000
# mean      0.115723    0.921384    1.578616     0.031572   13.764151
# std       0.096979    0.269563    1.053063     0.021061   29.238674
# min       0.000000    0.000000    0.000000     0.000000    1.000000
# ...

# %%
df_pp = lista_df_pp[NOTEBOOK]
df_pp[["titulo_pp", "k-1", "k-10", "k-50", 'match_rank', '1/match_rank']].describe()
# Out:
#               k-1        k-10        k-50  match_rank  1/match_rank
# count  520.000000  520.000000  520.000000  520.000000    520.000000
# mean     0.546154    0.857692    0.959615    9.511538      0.635785
# std      0.498345    0.349702    0.197049   28.883659      0.413503
# min      0.000000    0.000000    0.000000    1.000000      0.004032
# 25%      0.000000    1.000000    1.000000    1.000000      0.191667
# 50%      1.000000    1.000000    1.000000    1.000000      1.000000
# 75%      1.000000    1.000000    1.000000    5.250000      1.000000
# max      1.000000    1.000000    1.000000  248.000000      1.000000

# %%
df_pp = lista_df_pp[TV]
df_pp[["titulo_pp", "k-1", "k-1-qtd", "k-1-qtd/1", "k-10", "k-10-qtd", "k-10-qtd/10", "k-50", "k-50-qtd", "k-50-qtd/50", 'match_rank', 'match_rank/total', '1/match_rank']].describe()
# Out:
#               k-1     k-1-qtd   k-1-qtd/1        k-10   k-10-qtd  k-10-qtd/10  \
# count  376.000000  376.000000  376.000000  376.000000  376.00000   376.000000
# mean     0.377660    0.377660    0.377660    0.739362    1.06117     0.106117
# std      0.485448    0.485448    0.485448    0.439568    0.96553     0.096553
# min      0.000000    0.000000    0.000000    0.000000    0.00000     0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.00000     0.000000
# 50%      0.000000    0.000000    0.000000    1.000000    1.00000     0.100000
# 75%      1.000000    1.000000    1.000000    1.000000    1.00000     0.100000
# max      1.000000    1.000000    1.000000    1.000000    6.00000     0.600000
#
#              k-50    k-50-qtd  k-50-qtd/50  match_rank  match_rank/total  \
# count  376.000000  376.000000   376.000000  376.000000        376.000000
# mean     0.938830    1.601064     0.032021   13.135638          0.034935
# ...
